# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.io

# %% [markdown]
# # Figure 3 - Simulations data

# %% [markdown]
# ## Data obtained from simulations
#
#  <a id="top"></a>
#
# This data was obtained from running simulations of the model in Matlab 2016b.
#
# [1] [In vivo vs In vitro ramps](#traces)
#
# [2] [Max Intensity and Production (timer) distributions](#timer)
#
# [3] [Different prodction (timer) ramps due to noise](#ramps)

# %%
mat = scipy.io.loadmat('../Data/Figure 4/Figure 4 - simulations/Sample_traces_model.mat')

# %%
#fig = plt.figure(figsize=[6,8])
plt.style.use('default')
colors1 = ['limegreen', 'green','darkgreen']
colors2 = ['orange', 'darkorange','bisque']

dx = 8

fig, ax = plt.subplots(3, sharex=True, sharey=True, gridspec_kw={'hspace': 0}, figsize=[6,11])

    
for i in range(3):
    ax[i].plot(mat['In_vitro_time'],mat['In_vitro_PW'][:,i], color='grey', linewidth=3)
    ax[i].plot(mat['In_vitro_time'],mat['In_vitro_W'][:,i], color='limegreen', linewidth=3)
    ax[i].set_ylim([-1,12])
    if i != 2:
        ax[i].spines['top'].set_linewidth(0)
        ax[i].spines['bottom'].set_linewidth(0)
        ax[i].spines['left'].set_linewidth(0)
        ax[i].spines['right'].set_linewidth(0)
        ax[i].set_yticks([])
    else:
        ax[i].tick_params(width=2, length=4)
        ax[i].spines['top'].set_linewidth(0)
        ax[i].spines['bottom'].set_linewidth(2)
        ax[i].spines['left'].set_linewidth(0)
        ax[i].spines['right'].set_linewidth(0)
        ax[i].set_yticks([])

#plt.ylabel('$P(t)T/K_{0}$', fontsize=25)


        
plt.xlim([100,700])

plt.xticks(np.arange(100,800,200), fontsize=20)
plt.yticks([])


plt.xlabel('Time [min]', fontsize=25)
#plt.ylabel('$W(t)/K_{0}$', fontsize=25)


plt.show()

fig.savefig('../Data/Figure 4/Figure 4 - simulations/Results/SimulationTraces-Invitro-Big.pdf', bbox_inches='tight')

# %%
#fig = plt.figure(figsize=[6,8])
colors1 = ['limegreen', 'green','darkgreen']
colors2 = ['orange', 'darkorange','bisque']

dx = 8

fig, ax = plt.subplots(3, sharex=True, sharey=True, gridspec_kw={'hspace': 0}, figsize=[6,8])

    
for i in range(3):
    ax[i].plot(mat['In_vivo_time'],mat['In_vivo_PW'], color='grey', linewidth=3)
    ax[i].plot(mat['In_vivo_time'],mat['In_vivo_W'][:,i], color='limegreen', linewidth=3)
    ax[i].set_ylim([-1,12])
    if i != 2:
        ax[i].spines['top'].set_linewidth(0)
        ax[i].spines['bottom'].set_linewidth(0)
        ax[i].spines['left'].set_linewidth(0)
        ax[i].spines['right'].set_linewidth(0)
        ax[i].set_yticks([])
    else:
        ax[i].tick_params(width=2, length=4)
        ax[i].spines['top'].set_linewidth(0)
        ax[i].spines['bottom'].set_linewidth(2)
        ax[i].spines['left'].set_linewidth(0)
        ax[i].spines['right'].set_linewidth(0)
        ax[i].set_yticks([])

#plt.ylabel('$P(t)T/K_{0}$', fontsize=25)


        
plt.xlim([0,500])

plt.xticks(np.arange(0,600,100), fontsize=20)
plt.yticks([])


plt.xlabel('Time [min]', fontsize=25)
#plt.ylabel('$W(t)/K_{0}$', fontsize=25)


plt.show()

fig.savefig('../Data/Figure 4/Figure 4 - simulations/Results/SimulationTraces-Invivo-Big.pdf', bbox_inches='tight')

# %% [markdown]
# ### Timer Distributions
#
#  <a id="timer"></a>
#
#  If you want to go to the top of the notebook: [TOP](#top)

# %%
mat = scipy.io.loadmat('../Data/Figure 4/Figure 4 - simulations/Probability_distributions_Extrema_T.mat')
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'PT_max_in_vitro', 'PT_max_in_vivo', 'PT_min_in_vitro', 'PT_min_in_vivo', 'Pw_max_in_vitro', 'Pw_max_in_vivo', 'Pw_min_in_vitro', 'Pw_min_in_vivo', 'Rho_Td_simulated_in_vitro', 'Rho_Td_simulated_in_vivo', 'Rho_Tp_simulated_in_vitro', 'Rho_Tp_simulated_in_vivo', 'Rho_Wd_simulated_in_vitro', 'Rho_Wd_simulated_in_vivo', 'Rho_Wp_simulated_in_vitro', 'Rho_Wp_simulated_in_vivo', 'T_max_bin_in_vitro', 'T_max_bin_in_vivo', 'T_min_bin_in_vitro', 'T_min_bin_in_vivo', 'Td_simulated_in_vitro', 'Td_simulated_in_vivo', 'Tp_simulated_in_vitro', 'Tp_simulated_in_vivo', 'Wd_simulated_in_vitro', 'Wd_simulated_in_vivo', 'Wp_simulated_in_vitro', 'Wp_simulated_in_vivo', 'w_max_bin_in_vitro', 'w_max_bin_in_vivo', 'w_min_bin_in_vitro', 'w_min_bin_in_vivo'])

# %%
from matplotlib.legend_handler import HandlerLine2D, HandlerTuple

# %%
fig = plt.figure(figsize=[15,4])
plt.subplot(121)

m1, = plt.step(mat['Wp_simulated_in_vitro'][0],mat['Rho_Wp_simulated_in_vitro'][0], where='mid', 
         linewidth=2, color='darkcyan')
m2, = plt.step(mat['Wd_simulated_in_vitro'][0],mat['Rho_Wd_simulated_in_vitro'][0], where='mid', 
         linewidth=2, color='blue')
p1 = plt.scatter(mat['w_max_bin_in_vitro'],mat['Pw_max_in_vitro'], color='turquoise', s=60, 
            edgecolor='darkcyan', alpha=0.7)

p2 = plt.scatter(mat['w_min_bin_in_vitro'],mat['Pw_min_in_vitro'], color='deepskyblue', s=60,
           edgecolor='blue', alpha=0.7)

plt.xlim([0,10])
plt.ylim([0,3])

plt.legend([(m1, m2),(p1,p2)], ['Experiment', 'Simulation'], numpoints=1,
               handler_map={tuple: HandlerTuple(ndivide=None)}, fontsize=22)

plt.yticks(np.arange(0,4,1), fontsize=20)
plt.xticks(np.arange(0,12,2), fontsize=20)
ax = plt.gca()
ax.tick_params(width=2, length=4)
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)

plt.xlabel('$I/K_{0}$', fontsize=25)
plt.ylabel('$P(I/K_{0})$', fontsize=25)



plt.subplot(122)

m1, = plt.step(mat['Tp_simulated_in_vitro'][0],mat['Rho_Tp_simulated_in_vitro'][0], where='mid', 
         linewidth=2, color='mediumvioletred', label='Simulation')
m2, = plt.step(mat['Td_simulated_in_vitro'][0],mat['Rho_Td_simulated_in_vitro'][0], where='mid', 
         linewidth=2, color='darkorange', label='Simulation')
p1 = plt.scatter(mat['T_max_bin_in_vitro'],mat['PT_max_in_vitro'], color='hotpink', s=60, 
            edgecolor='mediumvioletred', alpha=0.7,  label='Experiment')
p2 = plt.scatter(mat['T_min_bin_in_vitro'],mat['PT_min_in_vitro'], color='bisque', s=60, 
            edgecolor='darkorange', alpha=0.7, label='Experiment')

plt.xlim([0,4])
plt.ylim([0,2])
plt.xticks(np.arange(0,5,1))
plt.yticks(np.arange(0,2.5,0.5))

plt.legend([(m1, m2),(p1,p2)], ['Experiment', 'Simulation'], numpoints=1,
               handler_map={tuple: HandlerTuple(ndivide=None)}, fontsize=22)


ax = plt.gca()
ax.tick_params(width=2, length=4)
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel(r'$Time/T_{0}$', fontsize=25)
plt.ylabel(r'$P(Time/T_{0})$', fontsize=25)






plt.show()

fig.savefig('../Data/Figure 4/Figure 4 - simulations/Results/Distributions-InVitro.pdf', 
           bbox_inches='tight')

# %%
fig = plt.figure(figsize=[6,4])

m1, = plt.step(mat['Wp_simulated_in_vitro'][0],mat['Rho_Wp_simulated_in_vitro'][0], where='mid', 
         linewidth=2, color='darkcyan')
m2, = plt.step(mat['Wd_simulated_in_vitro'][0],mat['Rho_Wd_simulated_in_vitro'][0], where='mid', 
         linewidth=2, color='blue')
p1 = plt.scatter(mat['w_max_bin_in_vitro'],mat['Pw_max_in_vitro'], color='turquoise', s=60, 
            edgecolor='darkcyan', alpha=0.7)

p2 = plt.scatter(mat['w_min_bin_in_vitro'],mat['Pw_min_in_vitro'], color='deepskyblue', s=60,
           edgecolor='blue', alpha=0.7)

plt.xlim([0,10])
plt.ylim([0,3])

plt.legend([(m1, m2),(p1,p2)], ['Simulation', 'Experiment'], numpoints=1,
               handler_map={tuple: HandlerTuple(ndivide=None)}, fontsize=22)

plt.yticks(np.arange(0,4,1), fontsize=20)
plt.xticks(np.arange(0,12,2), fontsize=20)
ax = plt.gca()
ax.tick_params(width=2, length=4)
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)

plt.xlabel('$I/K_{0}$', fontsize=25)
plt.ylabel('$P(I/K_{0})$', fontsize=25)

fig.savefig('../Data/Figure 4/Figure 4 - simulations/Results/Distributions-InVitro-PIntensity.pdf', 
           bbox_inches='tight')


fig = plt.figure(figsize=[6,4])

m1, = plt.step(mat['Tp_simulated_in_vitro'][0],mat['Rho_Tp_simulated_in_vitro'][0], where='mid', 
         linewidth=2, color='mediumvioletred', label='Simulation')
m2, = plt.step(mat['Td_simulated_in_vitro'][0],mat['Rho_Td_simulated_in_vitro'][0], where='mid', 
         linewidth=2, color='darkorange', label='Simulation')
p1 = plt.scatter(mat['T_max_bin_in_vitro'],mat['PT_max_in_vitro'], color='hotpink', s=60, 
            edgecolor='mediumvioletred', alpha=0.7,  label='Experiment')
p2 = plt.scatter(mat['T_min_bin_in_vitro'],mat['PT_min_in_vitro'], color='bisque', s=60, 
            edgecolor='darkorange', alpha=0.7, label='Experiment')

plt.xlim([0,4])
plt.ylim([0,2])
plt.xticks(np.arange(0,5,1))
plt.yticks(np.arange(0,2.5,0.5))

plt.legend([(m1, m2),(p1,p2)], ['Simulation', 'Experiment'], numpoints=1,
               handler_map={tuple: HandlerTuple(ndivide=None)}, fontsize=22)


ax = plt.gca()
ax.tick_params(width=2, length=4)
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel(r'$Time/T_{0}$', fontsize=25)
plt.ylabel(r'$P(Time/T_{0})$', fontsize=25)


fig.savefig('../Data/Figure 4/Figure 4 - simulations/Results/Distributions-InVitro-PTime.pdf', 
           bbox_inches='tight')

# %%
mat['T_max_bin_in_vitro'][0]
# Out:
# array([0.33658044, 0.44650956, 0.55643868, 0.6663678 , 0.77629692,
#        0.88622604, 0.99615515, 1.10608427, 1.21601339, 1.32594251,
#        1.43587163, 1.54580075, 1.65572987, 1.76565899, 1.87558811,
#        1.98551723, 2.09544635, 2.20537547, 2.31530458, 2.4252337 ,
#        2.53516282, 2.64509194, 2.75502106, 2.86495018, 2.9748793 ,
#        3.08480842, 3.19473754, 3.30466666, 3.41459578, 3.5245249 ,
#        3.63445401, 3.74438313, 3.85431225, 3.96424137, 4.07417049,
#        4.18409961, 4.29402873, 4.40395785, 4.51388697, 4.62381609,
#        4.73374521, 4.84367433, 4.95360344, 5.06353256, 5.17346168,
#        5.2833908 , 5.39331992, 5.50324904, 5.61317816, 5.72310728,
#        5.8330364 , 5.94296552, 6.05289464, 6.16282376])

# %%
fig = plt.figure(figsize=[6,4])

m1, = plt.step(mat['Wp_simulated_in_vivo'][0],mat['Rho_Wp_simulated_in_vivo'][0], where='mid', 
         linewidth=2, color='darkcyan')
m2, = plt.step(mat['Wd_simulated_in_vivo'][0],mat['Rho_Wd_simulated_in_vivo'][0], where='mid', 
         linewidth=2, color='blue')
p1 = plt.scatter(mat['w_max_bin_in_vivo'],mat['Pw_max_in_vivo'], color='turquoise', s=60, 
            edgecolor='darkcyan', alpha=0.7)

p2 = plt.scatter(mat['w_min_bin_in_vivo'],mat['Pw_min_in_vivo'], color='deepskyblue', s=60,
           edgecolor='blue', alpha=0.7)

plt.legend([(m1, m2),(p1,p2)], ['Simulation', 'Experiment'], numpoints=1,
               handler_map={tuple: HandlerTuple(ndivide=None)}, fontsize=22)

plt.xlim([0,10])
plt.ylim([0,3])


plt.yticks(np.arange(0,4,1), fontsize=20)
plt.xticks(np.arange(0,12,2), fontsize=20)
ax = plt.gca()
ax.tick_params(width=2, length=4)
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)

plt.xlabel('$I/K_{0}$', fontsize=25)
plt.ylabel('$P(I/K_{0})$', fontsize=25)

fig.savefig('../Data/Figure 4/Figure 4 - simulations/Results/Distributions-Invivo-PIntensity.pdf', 
           bbox_inches='tight')

fig = plt.figure(figsize=[6,4])

m1, = plt.step(mat['Tp_simulated_in_vivo'][0],mat['Rho_Tp_simulated_in_vivo'][0], where='mid', 
         linewidth=2, color='mediumvioletred')
m2, = plt.step(mat['Td_simulated_in_vivo'][0],mat['Rho_Td_simulated_in_vivo'][0], where='mid', 
         linewidth=2, color='darkorange')
p1 = plt.scatter(mat['T_max_bin_in_vivo'],mat['PT_max_in_vivo'], color='hotpink', s=60, 
            edgecolor='mediumvioletred', alpha=0.7)
p2 = plt.scatter(mat['T_min_bin_in_vivo'],mat['PT_min_in_vivo'], color='bisque', s=60, 
            edgecolor='darkorange', alpha=0.7)

plt.legend([(m1, m2),(p1,p2)], ['Simulation', 'Experiment'], numpoints=1,
               handler_map={tuple: HandlerTuple(ndivide=None)}, fontsize=22)

plt.xlim([0,4])
plt.ylim([0,2])
plt.xticks(np.arange(0,5,1))
plt.yticks(np.arange(0,2.5,0.5))
ax = plt.gca()
ax.tick_params(width=2, length=4)
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel(r'$Time/T_{0}$', fontsize=25)
plt.ylabel(r'$P(Time/T_{0})$', fontsize=25)


fig.savefig('../Data/Figure 4/Figure 4 - simulations/Results/Distributions-Invivo-PTime.pdf', 
           bbox_inches='tight')

# %% [markdown]
# ## Different production traces (due to noise)
#
#  <a id="ramps"></a>
#
# To go to the top of the notebook: [TOP](#top)

# %%
mat3 = scipy.io.loadmat('../Data/Figure 4/Figure 4 - simulations/Examples_ramps.mat')
mat3.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Deterministic_Ramp', 'Realization_1', 'Realization_2', 'Realization_3', 'Realization_4', 'Time'])

# %%
fig = plt.figure(figsize=[10,5])
plt.plot(mat3['Time'][0],mat3['Deterministic_Ramp'][0], color='black',linewidth=4,zorder=4)
plt.plot(mat3['Time'][0],mat3['Realization_1'][0], color='grey')
plt.plot(mat3['Time'][0],mat3['Realization_2'][0], color='darkgrey')
plt.plot(mat3['Time'][0],mat3['Realization_3'][0], color='slategrey')
plt.plot(mat3['Time'][0],mat3['Realization_4'][0], color='dimgrey')

plt.xlim([0,50])
plt.ylim([-1,12])

plt.xticks(np.arange(0,60,10),fontsize=20)
plt.yticks(np.arange(0,15,3),fontsize=20)
ax = plt.gca()
ax.tick_params(width=2, length=4)
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)

plt.ylabel('$P(t)}$', fontsize=25)
plt.xlabel('$Time$', fontsize=25)

fig.savefig('../Data/Figure 4/Figure 4 - simulations/Results/Ramps.pdf', bbox_inches='tight', transparent=True)
